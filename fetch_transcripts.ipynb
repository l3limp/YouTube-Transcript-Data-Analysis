# %%
import numpy as np
import pandas as pd
import json
import os
import json
import datetime
import time
from pprint import pprint
import google_auth_oauthlib.flow
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from youtube_transcript_api import YouTubeTranscriptApi,TranscriptsDisabled,NoTranscriptFound

import re
import concurrent.futures

# %%
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'
CLIENT_SECRETS_FILE = 'client_secret.json' 

YOUTUBE_CHANNEL_ID = "UCBJycsmduvYEL83R_U4JriQ"
CSV_NAME = 'mkbhd.csv'

SCOPES = [
    'https://www.googleapis.com/auth/youtube.readonly',
    'https://www.googleapis.com/auth/youtube.force-ssl',
    'https://www.googleapis.com/auth/youtubepartner-channel-audit',
    ]

# %%
df = pd.DataFrame(columns=['Id', 'Title', 'Published At', 'Captions', 'View Count', 'Like Count'])

# %%
def get_service():
        creds = None
        # The file token.json stores the user's access and refresh tokens, and is
        # created automatically when the authorization flow completes for the first time.
        if os.path.exists('token.json'):
            creds = Credentials.from_authorized_user_file('token.json', SCOPES)
            
        # If there are no (valid) credentials available, let the user log in.
        if not creds or not creds.valid:
            if creds and creds.expired and creds.refresh_token:
                creds.refresh(Request())
            else:
                flow = InstalledAppFlow.from_client_secrets_file(
                    CLIENT_SECRETS_FILE, SCOPES)
                creds = flow.run_local_server(port=0)
            # Save the credentials for the next run
            with open('token.json', 'w') as token:
                token.write(creds.to_json())

        try:
            return build(API_SERVICE_NAME, API_VERSION, credentials = creds)

        except HttpError as err:
            print(err)

# %%
def download_captions(item, stats):
    videoId = item['id']['videoId']
    title =  item['snippet']['title']
    publishedAt = item['snippet']['publishedAt']
    
    try:
        # Fetch the transcript
        srt = YouTubeTranscriptApi.get_transcript(videoId,languages=['en', 'en-US'])
        
        obj = {
            'id': videoId,
            'title': title,
            'publishedAt': publishedAt,
            'captions': srt
        }
        return obj, stats
        
    except TranscriptsDisabled:
        print(videoId, publishedAt, title.encode('utf-8'), '-- NO CAPTIONS')
        pass
    except NoTranscriptFound:
        print(videoId, publishedAt, title.encode('utf-8'), '-- NO CAPTIONS')
        pass
    
    return None, None

# %%
def saveDataToDF(item, stats):
    if(item is not None):
        df.loc[len(df.index)] = [item['id'], item['title'], item['publishedAt'], item['captions'], stats['viewCount'], stats['likeCount']]

# %%
def download_channel_captions(api, df, channelId, cutoff):
        publishedBefore = datetime.datetime.now() + datetime.timedelta(days=1)
        publishedBefore = publishedBefore.isoformat()+'Z'

        while True:
            futures = []
            # Get video results of the channel in batches of 50
            search_results = api.search().list(
                part="snippet",
                type="video",
                channelId=channelId,
                order='date',
                maxResults=50,
                publishedBefore=publishedBefore).execute()
            
            # Iterate through each video to fetch transcript and stats, then add to dataframe
            with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
                for search_result in search_results['items']:

                    # Note the date of publishing of earliest video in this batch, since we will fetch the next batch of videos from before it
                    currentDate=search_result['snippet']['publishedAt']
                    currentDate = datetime.datetime.strptime(currentDate,'%Y-%m-%dT%H:%M:%SZ') - datetime.timedelta(seconds=1)
                    currentDate = currentDate.isoformat()+'Z'
                    dt1 = datetime.datetime.fromisoformat(publishedBefore)
                    dt2 = datetime.datetime.fromisoformat(currentDate)

                    if(dt1 > dt2):
                        publishedBefore=currentDate

                    stats = api.videos().list(
                        id=search_result['id']['videoId'],
                        part="snippet,statistics",
                    ).execute()['items'][0]['statistics']

                    futures.append(executor.submit(download_captions, search_result, stats))

                for future in concurrent.futures.as_completed(futures):
                    try:
                        obj, stats = future.result()

                        # Save the data to the dataframe
                        saveDataToDF(obj, stats)
                    except Exception as exc:
                        print(f"Error fetching data: {exc}")
                        pass
                print(df.shape)

            # If we have reached the cutoff video number, break
            if df.shape[0] > cutoff:
                break
            if not search_results['items']:
                break

# %%
def summation(x):
    sum = 0
    for item in x:
        sum += item['duration']
    return sum

# %%
def count_words(x):
    cnt = 0
    for item in x:
        cnt += len(item['text'].split())
    return cnt

# %%
def get_sentences(x):
    sentences = []
    for item in x:
        sentences.append(item['text'])
    sentences = ' '.join(sentences)
    return sentences

# %%
def clean_data():
    df['Video Duration'] = 0
    df['CaptionsDuration'] = 0
    df['WordCount'] = 0
    
    df['Video Duration'] = df['Captions'].apply(lambda x: x[-1]['start'] + x[-1]['duration'] if x else None)
    df['CaptionsDuration'] = df['Captions'].apply(lambda x: summation(x) if x else None)
    df['WordCount'] = df['Captions'].apply(lambda x: count_words(x) if x else None)

    df['Captions'] = df['Captions'].apply(lambda x: get_sentences(x) if x else None)
    df['Captions'] = df['Captions'].apply(lambda x: x.replace('\n',' ') if x else None)
    df['Captions'] = df['Captions'].apply(lambda x: x.replace('-',' ') if x else None)
    df['Captions'] = df['Captions'].apply(lambda x: re.sub(r"\[.*?\]", "", x) if x else None)

    df['Words Per Minute'] = df['WordCount']*60/(df['CaptionsDuration'])
    df['Year'] = df['Published At'].apply(lambda x: int(datetime.datetime.strptime(x, '%Y-%m-%dT%H:%M:%SZ').year))

# %%
if not os.path.exists(CSV_NAME):
    api = get_service()
    download_channel_captions(api, df, YOUTUBE_CHANNEL_ID, 1100)
    clean_data()
    df.to_csv(CSV_NAME)
else:
    df = pd.read_csv(CSV_NAME)
# Out:
# (50, 6)
# (100, 6)
# (150, 6)
# U3JprndeVYU 2021-06-30T17:01:49Z b'Why Everything is an Ultrabook!' -- NO CAPTIONS
# ehv3zQAa9zM 2021-04-22T13:00:44Z b'Apple AirTags Unboxing &amp; Demo!' -- NO CAPTIONS
# 07mIwEa3xbQ 2021-04-26T23:20:48Z b'OnePlus Watch Review: They Settled!' -- NO CAPTIONS
# Error fetching data: 'viewCount'
# wUqZQTp_gpI 2021-04-11T22:01:55Z b'Top 5 Mercedes EQS Features: Electric Luxury!' -- NO CAPTIONS
# (195, 6)
# 8eNNJESKjrE 2021-03-23T15:01:27Z b'OnePlus 9 Pro Review: A Huge Hasselblad Promise!' -- NO CAPTIONS
# _fqxMZi7P7U 2021-01-20T00:01:24Z b'Xiaomi Mi 11: The New Normal!' -- NO CAPTIONS
# l4bNwGCx1FA 2020-11-27T14:00:19Z b'The FIRST MKBHD Product: ICONS!' -- NO CAPTIONS
# ThkMi9fkdEc 2018-06-19T18:25:18Z b'Let&#39;s Talk About Smartphone Chins!' -- NO CAPTIONS
# oD_3wMh5kLg 2018-05-21T21:28:49Z b'Top 5 Smartphone Cameras: The Blind Test! [2018]' -- NO CAPTIONS
# (466, 6)
# KvNis_A6UaI 2017-10-24T04:02:36Z b'Google Pixel 2 Review: This Thing is Smart!' -- NO CAPTIONS
# 2iObySa91b0 2017-10-05T04:39:48Z b'Google Pixel 2 Impressions!' -- NO CAPTIONS
# -_WbmSxZnB8 2017-08-22T20:56:49Z b'Essential Phone Impressions!' -- NO CAPTIONS
# (513, 6)
# 2BQ1rCqG19Y 2017-06-23T21:02:08Z b'Starting a Vlog? OnePlus Cheating? Ask MKBHD V17!' -- NO CAPTIONS
# ZPY7dIz0GBI 2017-05-24T22:43:29Z b'$500 Drone vs $3000 Drone - DJI Spark vs Inspire 1!' -- NO CAPTIONS
# VDsjYTMyh94 2017-03-21T22:26:42Z b'New RED iPhone 7 Unboxing!' -- NO CAPTIONS
# (560, 6)
# 1cpUwbr5YyE 2016-11-29T22:13:40Z b'Google Home Review: Assistant in a Box!' -- NO CAPTIONS
# xQLb_uwWzj8 2016-10-08T01:50:45Z b'Dope Tech: Self-Lacing Nike Mag!' -- NO CAPTIONS
# uVRcbo9_OdA 2016-09-08T04:04:41Z b'iPhone 7 Impressions: 10 New Things!' -- NO CAPTIONS
# (607, 6)
# V2nPsyyme5I 2016-03-09T18:53:19Z b'Samsung Galaxy S7 Edge: Biggest Flaws!' -- NO CAPTIONS
# QkcJL_FARp8 2016-01-10T00:08:06Z b'RED Raven Impressions: 4.5K!' -- NO CAPTIONS
# (655, 6)
# Mhvv2-iCKao 2015-04-22T05:31:26Z b'Samsung Galaxy S6 Review!' -- NO CAPTIONS
# (704, 6)
# Wwp9eaVVW_8 2014-10-20T18:13:16Z b'Apple iPhone 6+ Review!' -- NO CAPTIONS
# wspZXjeWWq4 2014-10-05T20:00:08Z b'Nexus 6 (Shamu) Thoughts!' -- NO CAPTIONS
# (752, 6)
# tYGg1fIfuOY 2014-01-11T14:36:55Z b'Best Cars of CES 2014!' -- NO CAPTIONS
# (801, 6)
# 3GrIWdORHvc 2013-12-05T23:45:58Z b'Oppo N1 Review! (Cyanogenmod Phone)' -- NO CAPTIONS
# (850, 6)
# (900, 6)
# ddI-ZZwFclc 2012-07-23T20:30:03Z b'Asus Transformer Pad Infinity Review!' -- NO CAPTIONS
# (949, 6)
# nY15RGU2QJM 2012-06-11T21:26:30Z b'Google Innovation at WWDC 2012!' -- NO CAPTIONS
# SvGlDmfoF9o 2012-03-19T17:37:13Z b'The New iPad 3! [Teaser]' -- NO CAPTIONS
# (997, 6)
# nDSy7JVenss 2011-11-03T17:44:49Z b'Google Does a Barrel Roll' -- NO CAPTIONS
# Xt2tBXTOBVM 2011-10-05T16:22:42Z b'Nexus Prime Teaser' -- NO CAPTIONS
# ui_ItunKJvc 2011-08-11T21:42:44Z b'IndiSLIDER Mini Deluxe [Canon T2i]' -- NO CAPTIONS
# (1044, 6)
# RhUL8whVGW0 2011-01-06T02:09:53Z b'Android 3.0 - Honeycomb!' -- NO CAPTIONS
# Error fetching data: 'likeCount'
# Error fetching data: 'likeCount'
# LgBS0Kv08UU 2010-08-09T20:42:18Z b'New MKBHD Intro' -- NO CAPTIONS
# Error fetching data: 'likeCount'
# Rf_TNp_ReS4 2010-07-26T16:11:41Z b'How to Play Snake on YouTube Videos' -- NO CAPTIONS
# 2Hqmru-NV30 2010-07-17T17:53:31Z b'MKBHD Update 6.0' -- NO CAPTIONS
# Error fetching data: 'likeCount'
# Error fetching data: 'likeCount'
# (1085, 6)
# ijgAj_FFaH0 2010-05-18T19:41:32Z b'Unboxed: Intel X25-V 40GB SSD' -- NO CAPTIONS
# Uq6VHuXSklQ 2010-04-13T22:43:29Z b'MKBHD Search Story' -- NO CAPTIONS
# JoJeOZESiLs 2010-03-11T23:03:27Z b'Need for Speed Most Wanted Gameplay' -- NO CAPTIONS
# LlgXO_DwSRA 2010-02-23T22:29:48Z b'Unboxed: Cyber Acoustics 2.1 Speakers [HD]' -- NO CAPTIONS
# Al1_W7dsT9I 2010-01-28T00:57:24Z b'The iPad Rant' -- NO CAPTIONS
# LaEWflVQDWA 2009-12-22T20:50:01Z b'Reviewed: Motorola DROID [HD]' -- NO CAPTIONS
# JVUtycSK85Y 2009-11-24T03:33:06Z b'Wrapsol for the Zune HD' -- NO CAPTIONS
# EO8mcXpx7tY 2009-11-10T00:10:16Z b'Time Lapse Video Editing' -- NO CAPTIONS
# Error fetching data: 'likeCount'
# (1126, 6)

# %%
print(df.head(5))
# Out:
#             Id                                              Title  \
# 0  GQkkHtBD1BM            Taking 1000 Steps  In Every Smartwatch!
# 1  B3szaVzQx0o       Google Pixel 8A Impressions: Just Get The 8!
# 2  8reaJG7z-is  I Visited Apple&#39;s Secret iPhone Testing Labs!
# 3  B-d97ZrAJZ0          OnePlus 12 Review: Better Than You Think!
# 4  CjWfgSrwrz0         Apple Vision Pro Hidden Feature ✈️ #protip
#
#            Published At                                           Captions  \
# 0  2024-01-19T23:44:36Z  I'm curious how accurate the step counters are...
# 1  2024-05-07T16:18:33Z  (bright music)   All right, so there is just o...
# 2  2024-06-07T21:31:09Z  ♪ Ah, ah, ah, yeah, yeah ♪ ♪ Ah, ah, ah, yeah,...
# 3  2024-02-09T03:45:25Z  (smooth music)   All right, now that we're bac...
# 4  2024-02-09T22:20:23Z  okay so one of the best features of the Vision...
#
#   View Count Like Count  Video Duration  CaptionsDuration  WordCount  \
# 0   13451274     515806          61.640           116.961        152
# 1    2445129      83538         441.624           440.281       1453
# 2    2904968     124954         650.129           642.563       2172
# 3    3073994      88402         888.356           885.623       2889
# 4    5094568     226995          61.079           120.598        217
#
#    Words Per Minute  Year
# 0         77.974710  2024
# 1        198.009907  2024
# 2        202.812798  2024
# 3        195.726624  2024
# 4        107.961989  2024
